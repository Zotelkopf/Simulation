# %% [markdown]
# ### 0. Imports and Generators

# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.default_rng()
dist_normal = lambda x, mu, sigma: 1 / (np.sqrt(2 * np.pi) * sigma) * \
                                   np.exp(-(x - mu)**2 / (2 * sigma**2))

# %% [markdown]
# ### 1. Gaußverteilung

# %%
sample_size_normal = 1000
mean = 5
std = 2

# %%
sample_normal = rng.normal(mean, std, sample_size_normal)
sample_normal[:5]
# Out:
# array([3.16715103, 9.44377757, 2.87222239, 1.42934076, 7.38559724])

# %%
bin_count = 50
_, bins, _ = plt.hist(sample_normal, bins=bin_count, density=True)
x = np.linspace(bins[0], bins[-1], 1000)
plt.plot(x, dist_normal(x, mean, std), color='red', lw=2)
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$p(x)$', fontsize=14)
plt.show()

# %% [markdown]
# ### 2. Zentraler Grenzwertsatz

# %%
N = 1000
M = 100
sample_size_uniform = (N, M)
sample_uniform = rng.uniform(1, 3, sample_size_uniform)
sample_uniform[:5, 0]
# Out:
# array([1.80101624, 1.33079636, 2.57505546, 1.07696334, 1.06475866])

# %%
mean = sample_uniform.mean()
std = sample_uniform.std(ddof=1)
mean, std
# Out:
# (1.9989088579245256, 0.5776611373743475)

# %%
sample_sum = sample_uniform.sum(axis=1)
sample_sum[:5]
# Out:
# array([190.12940052, 203.91762837, 199.30082992, 203.44809757,
#        201.5082818 ])

# %%
bin_count = 50
_, bins, _ = plt.hist(sample_sum, bins=bin_count, density=True)
x = np.linspace(bins[0], bins[-1], 1000)
plt.plot(x, dist_normal(x, M*mean, np.sqrt(M)*std), color='red', lw=2)
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$p(x)$', fontsize=14)
plt.show()

# %% [markdown]
# ### 3. Binomialverteilung

# %%
N = 10000
p = 0.4
sample_size_binomial = 1000

# %%
sample_binomial = rng.binomial(N, p, sample_size_binomial)
sample_binomial[:5]
# Out:
# array([4026, 4065, 3983, 4016, 4101], dtype=int64)

# %%
bin_count = 50
_, bins, _ = plt.hist(sample_binomial, bins=bin_count, density=True)
x = np.linspace(bins[0], bins[-1], 1000)
plt.plot(x, dist_normal(x, p*N, np.sqrt(N*p*(1-p))), color='red', lw=2)
plt.xlabel(r'$N_1$', fontsize=14)
plt.ylabel(r'$p(N_1)$', fontsize=14)
plt.show()
